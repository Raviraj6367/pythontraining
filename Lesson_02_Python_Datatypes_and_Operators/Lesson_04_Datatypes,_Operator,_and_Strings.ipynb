# %%
print('Hey Everyone!!! Welcome to the world of Python!!')
# Out:
# Hey Everyone!!! Welcome to the world of Python!!

# %% [markdown]
# # Data Types

# %%
x = ' '
print(x)
print(bool(x))
# Out:
#
# True

# %%
# declare an integer
# int x = 5;
#python
x=5
print(type(x))
# Out:
# <class 'int'>

# %%
#floating point inegers have decimal in them.
# float y = 10.0
y = 10.0
print(type(y))
# Out:
# <class 'float'>

# %%
z = True
print(type(z))
# Out:
# <class 'bool'>

# %%
x = 34 ; y = 67.89 ; z = True
print('Value of: \nx is =', x, '\ny is =',y, '\nz is =', z) # single quotes or double quotes.
# Out:
# Value of:
# x is = 34
# y is = 67.89
# z is = True

# %%
print('Type of \nx = ', type(x), '\ty = ', type(y), '\tz = ', type(z))
# Out:
# Type of
# x =  <class 'int'> 	y =  <class 'float'> 	z =  <class 'bool'>

# %%
var = "abc"
print('var = ', var)
print('type of var ', type(var))
# Out:
# var =  abc
# type of var  <class 'str'>

# %% [markdown]
# ## Data Type Conversion
# Data type conversion in Python refers to the process of converting a value from one data type to another.

# %%
x='100.0'#--> String--> Float--> INT, '100.0'-->100.0 --> 100
print(int(float(x))) # 10
# Out:
# 100

# %%
x = 45.77 # float
int(x)
# Out:
# 45

# %%
str(x)
# Out:
# '45.77'

# %%
bool(x)
# Out:
# True

# %%
x=0 # When converted to bool only numeric zero returns false, all other numeric values return true.

bool(x)
# Out:
# False

# %%
z='' # When talking about a string, it returns false when the string is a blank character else it reutrns true always.
bool(z)
# Out:
# True

# %%
y = '45.88' # Convert the string value to intger.
 # Converting string to flaot to make it a base 10 number,
int(float(y)) # string--> float--> int.
# Out:
# 45

# %%
float(y)
# Out:
# 45.88

# %%
int(float(y))
# Out:
# 45

# %%
x=2 # If we do type conversion to Boolean, then we wont be able to revert to original value.
int(bool(x))
# Out:
# 1

# %%
x=''
float(bool(x))
# Out:
# 0.0

# %%
# Try all the possible combinations of cenversion between data types.
# x='

# %% [markdown]
# ## Checking References
# Checking references in Python involves determining whether two variables reference the same object in memory using the id() function.

# %%
x = 34
y = x # Hey y!!!! go ahead and point to x.
print('x = ', x, ';  id of x = ', id(x))
print('y = ', y, ';  id of y = ', id(y))
# Out:
# x =  34 ;  id of x =  11655432
# y =  34 ;  id of y =  11655432

# %%
z= 34
print(id(x))
print(id(z))
# Out:
# 11655432
# 11655432

# %%
x = 356
print('x = ', x, ';  id of x = ', id(x))
print('y = ', y, ';  id of y = ', id(y))
# Out:
# x =  356 ;  id of x =  134140246519504
# y =  34 ;  id of y =  11655432

# %%
y = 356
print('x = ', x, ';  id of x = ', id(x))
print('y = ', y, ';  id of y = ', id(y))
# Out:
# x =  356 ;  id of x =  134140246519504
# y =  356 ;  id of y =  134140246510576

# %%
x= 34.5
y=34.5
print('x = ', x, ';  id of x = ', id(x))
print('y = ', y, ';  id of y = ', id(y))
# Out:
# x =  34.5 ;  id of x =  133470768895376
# y =  34.5 ;  id of y =  133470768894832

# %%
x=1000
y=x
print(id(x))
print(id(y))
# Out:
# 134140246514352
# 134140246514352

# %%
x=200
print(id(x))
print(id(y))
# Out:
# 11660744
# 134140246514352

# %% [markdown]
# # Arithmetic Operators

# %%
x = 50
y = 4

# %%
print('Sum of x & y                   : ', x + y)
print('Difference between x & y       : ', x - y)
print('Product of x & y               : ', x * y)
print('Division of x by y             : ', x / y)
# Out:
# Sum of x & y                   :  54
# Difference between x & y       :  46
# Product of x & y               :  200
# Division of x by y             :  12.5

# %%
print('Remainder of x divided by y    : ', x % y)
print('Floor Division x divided by y  : ', x // y)
print('Exponential value for x raised to power y : ', x ** y)
# Out:
# Remainder of x divided by y    :  2
# Floor Division x divided by y  :  12
# Exponential value for x raised to power y :  6250000

# %% [markdown]
# # Arithmetic Assignment Operators

# %%
a = 10
print('Present value of a = ', a )
# Out:
# Present value of a =  10

# %%
a += 5
print('Updated value of a = ', a )
# Out:
# Updated value of a =  15

# %%
a = 10
print('Present value of a = ', a )
print('Present id of a = ', id(a))
# Out:
# Present value of a =  10
# Present id of a =  140563811107344

# %%
a += 15
print('Updated value of a = ', a )
print('Updated id of a = ', id(a))
# Out:
# Updated value of a =  25
# Updated id of a =  140563811107824

# %% [markdown]
# # Comparison Operator

# %%
a = 20
b = 20
print('a = ', a, '  b = ', b)
print('a == b  : ', a == b)
# Out:
# a =  20   b =  20
# a == b  :  True

# %%
a = 20
b = 30
print('a = ', a, '  b = ', b)
print('a != b  : ', a != b)
# Out:
# a =  20   b =  30
# a != b  :  True

# %%
a = 40
b = 30
print('a = ', a, '  b = ', b)
print('a <= b  : ', a <= b)
# Out:
# a =  40   b =  30
# a <= b  :  False

# %%
a = 30
b = 30
print('a = ', a, '  b = ', b)
print('a >= b  : ', a >= b)
# Out:
# a =  30   b =  30
# a >= b  :  True

# %% [markdown]
# # Logical Operators

# %%
a = 30
b = 30
print('a = ', a, '  b = ', b)
print('a < b            : ', a < b)
print('a == b           : ', a == b)
# Out:
# a =  30   b =  30
# a < b            :  False
# a == b           :  True

# %%
print('a < b and a == b : ', a < b and a == b)
# Out:
# a < b and a == b :  False

# %%
a = 30
b = 30
print('a = ', a, '  b = ', b)
print('a < b           : ', a < b)
print('a == b          : ', a == b)
# Out:
# a =  30   b =  30
# a < b           :  False
# a == b          :  True

# %%
print('a < b or a == b : ', a < b or a == b) ##  ||--> or , && --> and,
# Out:
# a < b or a == b :  True

# %%
a = 40
print('a = ', a)
print('a < 50      : ' , a < 50 )
# Out:
# a =  40
# a < 50      :  True

# %%
print('not a < 50  : ' , not(a < 50)) # ! --> not
# Out:
# not a < 50  :  False

# %% [markdown]
# # Miscellaneous Operators

# %% [markdown]
# ### Identity Operators

# %%
a = ['a', 'b', 'c'] # returns true if reference of two variables is same.
b = ['a', 'b', 'c']
print('ID of A: ', id(a))
print('ID of B: ', id(b))
print('a is b' , a is b)
# Out:
# ID of A:  134140259474304
# ID of B:  134140259423872
# a is b False

# %%
a=12
b=12
print('ID of A: ', id(a))
print('ID of B: ', id(b))
print('a is b' , a is b)
# Out:
# ID of A:  11654728
# ID of B:  11654728
# a is b True

# %%
a=1000
b=1000
print('ID of A: ', id(a))
print('ID of B: ', id(b))
print('a is b' , a is b)
# Out:
# ID of A:  134140246519600
# ID of B:  134140246515792
# a is b False

# %%
a = ['a', 'b', 'c']
b =  a
print('a is b' , a is b)
# Out:
# a is b True

# %%
id(a) == id(b)
# Out:
# True

# %%
a = ['a', 'b', 'c']
b = ['a', 'b', 'c']
print('a is not b' , a is not b)
# Out:
# a is not b True

# %% [markdown]
# ### Membership Operators

# %%
x = 'a'
y = 'Dictionary'
print(x , ' in "', y, '"')
print( x in y)
# Out:
# a  in " Dictionary "
# True

# %%
x = 'a'
y = 'Dictionary'
print(x , ' in "', y, '"')
print( x not in y)
# Out:
# a  in " Dictionary "
# False

# %%
a = [20, 45, 10]
10 in a
# Out:
# True

# %%
a = [20, 45, 10]
10 not in a
# Out:
# False

# %% [markdown]
# # Strings in Python

# %%
message_1 = 'Hi! Welcome to Python Programming!!'
message_2 = "Hi! Welcome to Python Programming!!"
print(message_1)
print(message_2)
# Out:
# Hi! Welcome to Python Programming!!
# Hi! Welcome to Python Programming!!

# %%
message_1 = 'Hi! Welcome to "Python Programming"!!'
message_2 = "Hi! Welcome to 'Python Programming'!!"
print(message_1)
print(message_2)
# Out:
# Hi! Welcome to "Python Programming"!!
# Hi! Welcome to 'Python Programming'!!

# %% [markdown]
# # String Methods

# %%
sent = 'She seLLs sEa SHELLS oN tHe SeA sHoRe.'
upper_case = sent.upper()
print(upper_case)
# Out:
# SHE SELLS SEA SHELLS ON THE SEA SHORE.

# %%
lower_case = sent.lower()
print(lower_case)
# Out:
# she sells sea shells on the sea shore.

# %%
sentence = sent.capitalize()
print(sentence)
# Out:
# She sells sea shells on the sea shore.

# %%
word_upper = sent.title()
word_upper
# Out:
# 'She Sells Sea Shells On The Sea Shore.'
